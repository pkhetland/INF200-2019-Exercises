# %%
import matplotlib.pyplot as plt
plt.rcParams["patch.force_edgecolor"] = True

from snakes_and_ladders import *

# %%
p_seed, p_positions, p_steps = \
            multi_game_experiment(100, 1,randint(1, 999))

plt.hist(p_steps, histtype='bar') #bar gives boundaries
plt.title("$Player = 1 , N= 100$")
plt.xlabel('Number of steps')
plt.show()

#Use the same seed that was generated above
for j in (2,4,8):
    seed, p_positions, p_steps = \
            multi_game_experiment(100, j, p_seed)
    plt.hist(p_steps, histtype='bar') 
    plt.title("$Player = {} ,N= 100$ ".format(j))
    plt.xlabel('Number of steps')
    plt.show()
